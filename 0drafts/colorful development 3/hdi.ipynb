# %%
import numpy as np, requests, pandas as pd

# %%
df=pd.read_excel("http://www.happyplanetindex.org/assets/hpi-data.xlsx",sheetname="Complete HPI Dataset",skiprows=5)

# %%
df
# Out:
#      Unnamed: 0  HPI Rank                   Country Sub-Region  \
# 0           NaN       109               Afghanistan         3b
# 1           NaN        18                   Albania         7b
# 2           NaN        26                   Algeria         3a
# 3           NaN       127                    Angola         4a
# 4           NaN        17                 Argentina         1b
# 5           NaN        53                   Armenia         7a
# 6           NaN        76                 Australia         2a
# 7           NaN        48                   Austria         2c
# 8           NaN        80                Azerbaijan         7a
# 9           NaN       146                   Bahrain         3b
# 10          NaN        11                Bangladesh         5a
# 11          NaN       103                   Belarus         7c
# 12          NaN       107                   Belgium         2c
# 13          NaN         4                    Belize         1a
# 14          NaN       132                     Benin         4c
# 15          NaN        64                   Bolivia         1b
# 16          NaN        74    Bosnia and Herzegovina         7b
# 17          NaN       151                  Botswana         4a
# 18          NaN        21                    Brazil         1b
# 19          NaN       123                  Bulgaria         7b
# 20          NaN       129              Burkina Faso         4c
# 21          NaN       135                   Burundi         4b
# 22          NaN        85                  Cambodia         6c
# 23          NaN       124                  Cameroon         4c
# 24          NaN        65                    Canada         2b
# 25          NaN       148  Central African Republic         4a
# 26          NaN       150                      Chad         4b
# 27          NaN        19                     Chile         1b
# 28          NaN        60                     China         6a
# 29          NaN         3                  Colombia         1b
# ..          ...       ...                       ...        ...
# 121         NaN        90                 Singapore         6b
# 122         NaN        89                  Slovakia         7b
# 123         NaN        87                  Slovenia         7b
# 124         NaN       142              South Africa         4a
# 125         NaN        62                     Spain         2e
# 126         NaN        35                 Sri Lanka         5a
# 127         NaN       101                     Sudan         4b
# 128         NaN        52                    Sweden         2d
# 129         NaN        34               Switzerland         2c
# 130         NaN        47                     Syria         3b
# 131         NaN        43                Tajikistan         7a
# 132         NaN       133                  Tanzania         4b
# 133         NaN        20                  Thailand         6c
# 134         NaN       141                      Togo         4c
# 135         NaN       136       Trinidad and Tobago         1a
# 136         NaN        39                   Tunisia         3a
# 137         NaN        44                    Turkey         3b
# 138         NaN        95              Turkmenistan         7a
# 139         NaN       131                    Uganda         4b
# 140         NaN       100                   Ukraine         7c
# 141         NaN       130      United Arab Emirates         3b
# 142         NaN        41            United Kingdom         2c
# 143         NaN       105  United States of America         2b
# 144         NaN        93                   Uruguay         1c
# 145         NaN        54                Uzbekistan         7a
# 146         NaN         9                 Venezuela         1b
# 147         NaN         2                   Vietnam         6c
# 148         NaN        68                     Yemen         3b
# 149         NaN        99                    Zambia         4a
# 150         NaN       115                  Zimbabwe         4a
#
#      Life \nExpectancy  Well-being\n(0-10)  Happy Life Years  \
# 0                 48.7            4.758381         28.963890
# 1                 76.9            5.268937         48.771132
# 2                 73.1            5.236961         46.180395
# 3                 51.1            4.206092         28.209269
# 4                 75.9            6.441067         55.015278
# 5                 74.2            4.367811         41.889160
# 6                 81.9            7.405616         65.471978
# 7                 80.9            7.346036         64.299900
# 8                 70.7            4.218611         39.097695
# 9                 75.1            4.549466         43.452009
# 10                68.9            4.985649         42.188328
# 11                70.3            5.525923         45.982110
# 12                80.0            6.853514         60.538204
# 123                 5.211424           40.174398     2049000     ...
# 124                 2.589261           28.190112    49991000     ...
# 125                 4.740126           44.062793    46071000     ...
# 126                 1.206349           49.382588    20860000     ...
# 127                 1.630335           37.573654    43552000     ...
# 128                 5.708356           46.172373     9378000     ...
# 129                 5.013067           50.338647     7826000     ...
# 130                 1.454491           47.119819    20447000     ...
# 131                 0.900643           47.789313     6879000     ...
# 132                 1.192383           30.740735    44841000     ...
# 133                 2.411845           53.457642    69122000     ...
# 134                 1.031873           28.231490     6028000     ...
# 135                 7.559942           30.267267     1341000     ...
# 136                 1.764818           48.298366    10549000     ...
# 137                 2.554785           47.623544    72752000     ...
# 138                 3.983001           39.078872     5042000     ...
# 139                 1.565490           31.526206    33424000     ...
# 140                 3.193976           37.583250    45871000     ...
# 141                 8.880909           31.778274     7512000     ...
# 142                 4.713110           47.925476    62232000     ...
# 143                 7.189133           37.340106   309349000     ...
# 144                 5.078661           39.320977     3357000     ...
# 145                 1.819812           46.002763    28228000     ...
# 146                 3.024572           56.871442    28834000     ...
# 147                 1.390974           60.438991    86928000     ...
# 148                 0.871183           42.966753    24053000     ...
# 149                 0.840814           37.733570    12927000     ...
# 150                 1.170250           35.317168    12571000     ...
#
#      Unnamed: 22 Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  \
# 0            NaN         NaN          NaN          NaN          NaN
# 1            NaN         NaN          NaN          NaN          NaN
# 2            NaN         NaN          NaN          NaN          NaN
# 3            NaN         NaN          NaN          NaN          NaN
# 4            NaN         NaN          NaN          NaN          NaN
# 5            NaN         NaN          NaN          NaN          NaN
# 6            NaN         NaN          NaN          NaN          NaN
# 7            NaN         NaN          NaN          NaN          NaN
# 8            NaN         NaN          NaN          NaN          NaN
# 9            NaN         NaN          NaN          NaN          NaN
# 10           NaN         NaN          NaN          NaN          NaN
# 11           NaN         NaN          NaN          NaN          NaN
# 12           NaN         NaN          NaN          NaN          NaN
# 13           NaN         NaN          NaN          NaN          NaN
# 14           NaN         NaN          NaN          NaN          NaN
# 15           NaN         NaN          NaN          NaN          NaN
# 16           NaN         NaN          NaN          NaN          NaN
# 17           NaN         NaN          NaN          NaN          NaN
# 18           NaN         NaN          NaN          NaN          NaN
# 19           NaN         NaN          NaN          NaN          NaN
# 20           NaN         NaN          NaN          NaN          NaN
# 21           NaN         NaN          NaN          NaN          NaN
# 22           NaN         NaN          NaN          NaN          NaN
# 23           NaN         NaN          NaN          NaN          NaN
# 24           NaN         NaN          NaN          NaN          NaN
# 25           NaN         NaN          NaN          NaN          NaN
# 26           NaN         NaN          NaN          NaN          NaN
# 27           NaN         NaN          NaN          NaN          NaN
# 28           NaN         NaN          NaN          NaN          NaN
# 29           NaN         NaN          NaN          NaN          NaN
# ..           ...         ...          ...          ...          ...
# 121          NaN         NaN          NaN          NaN          NaN
# 122          NaN         NaN          NaN          NaN          NaN
# 123          NaN         NaN          NaN          NaN          NaN
# 124          NaN         NaN          NaN          NaN          NaN
# 125          NaN         NaN          NaN          NaN          NaN
# 126          NaN         NaN          NaN          NaN          NaN
# 127          NaN         NaN          NaN          NaN          NaN
# 128          NaN         NaN          NaN          NaN          NaN
# 129          NaN         NaN          NaN          NaN          NaN
# 135         NaN         NaN          NaN          NaN          NaN
# 136         NaN         NaN          NaN          NaN          NaN
# 137         NaN         NaN          NaN          NaN          NaN
# 138         NaN         NaN          NaN          NaN          NaN
# 139         NaN         NaN          NaN          NaN          NaN
# 140         NaN         NaN          NaN          NaN          NaN
# 141         NaN         NaN          NaN          NaN          NaN
# 142         NaN         NaN          NaN          NaN          NaN
# 143         NaN         NaN          NaN          NaN          NaN
# 144         NaN         NaN          NaN          NaN          NaN
# 145         NaN         NaN          NaN          NaN          NaN
# 146         NaN         NaN          NaN          NaN          NaN
# 147         NaN         NaN          NaN          NaN          NaN
# 148         NaN         NaN          NaN          NaN          NaN
# 149         NaN         NaN          NaN          NaN          NaN
# 150         NaN         NaN          NaN          NaN          NaN
#
# [151 rows x 32 columns]

# %%
url='http://api.worldbank.org/v2/en/indicator/ny.gdp.pcap.pp.kd?downloadformat=csv'
filename='ny.gdp.pcap.pp.kd_Indicator_en_csv_v2.csv'
r = requests.get(url)
z = zipfile.ZipFile(StringIO.StringIO(r.content))
gdp=pd.read_csv(z.open(filename),skiprows=[0,1]).drop('Unnamed: 58',axis=1).drop('Indicator Code',axis=1)
gdp.head(2)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1      Andorra          AND
#
#                                       Indicator Name  1961  1962  1963  1964  \
# 0  GDP per capita, PPP (constant 2011 internation...   NaN   NaN   NaN   NaN
# 1  GDP per capita, PPP (constant 2011 internation...   NaN   NaN   NaN   NaN
#
#    1965  1966  1967  ...   2005  2006  2007  2008  2009  2010          2011  \
# 0   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN  36016.483757
# 1   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN           NaN
#
#    2012  2013  2014
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
#
# [2 rows x 57 columns]

# %%
url='http://api.worldbank.org/v2/en/indicator/ny.gnp.pcap.pp.kd?downloadformat=csv'
filename='ny.gnp.pcap.pp.kd_Indicator_en_csv_v2.csv'
r = requests.get(url)
z = zipfile.ZipFile(StringIO.StringIO(r.content))
gnp=pd.read_csv(z.open(filename),skiprows=[0,1]).drop('Unnamed: 58',axis=1).drop('Indicator Code',axis=1)
gnp.head(2)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1      Andorra          AND
#
#                                       Indicator Name  1961  1962  1963  1964  \
# 0  GNI per capita, PPP (constant 2011 internation...   NaN   NaN   NaN   NaN
# 1  GNI per capita, PPP (constant 2011 internation...   NaN   NaN   NaN   NaN
#
#    1965  1966  1967  ...   2005  2006  2007  2008  2009  2010  2011  2012  \
# 0   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2013  2014
# 0   NaN   NaN
# 1   NaN   NaN
#
# [2 rows x 57 columns]

# %%
url='http://api.worldbank.org/v2/en/indicator/sp.dyn.le00.in?downloadformat=csv'
filename='sp.dyn.le00.in_Indicator_en_csv_v2.csv'
r = requests.get(url)
z = zipfile.ZipFile(StringIO.StringIO(r.content))
le=pd.read_csv(z.open(filename),skiprows=[0,1]).drop('Unnamed: 58',axis=1).drop('Indicator Code',axis=1)
le.head(2)
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Life expectancy at birth, total (years)
# 1      Andorra          AND  Life expectancy at birth, total (years)
#
#         1961       1962       1963       1964       1965    1966       1967  \
# 0  65.988024  66.365537  66.713976  67.044293  67.369756  67.699  68.034683
# 1        NaN        NaN        NaN        NaN        NaN     NaN        NaN
#
#      ...           2005       2006       2007      2008       2009       2010  \
# 0    ...      74.228073  74.375707  74.526244  74.67422  74.816146  74.952024
# 1    ...            NaN        NaN        NaN       NaN        NaN        NaN
#
#        2011       2012  2013  2014
# 0  75.08039  75.206756   NaN   NaN
# 1       NaN        NaN   NaN   NaN
#
# [2 rows x 57 columns]

# %%
url='http://api.worldbank.org/v2/en/indicator/se.adt.litr.zs?downloadformat=csv'
filename='se.adt.litr.zs_Indicator_en_csv_v2.csv'
r = requests.get(url)
z = zipfile.ZipFile(StringIO.StringIO(r.content))
alr=pd.read_csv(z.open(filename),skiprows=[0,1]).drop('Unnamed: 58',axis=1).drop('Indicator Code',axis=1)
alr.head(2)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1      Andorra          AND
#
#                                       Indicator Name  1961  1962  1963  1964  \
# 0  Literacy rate, adult total (% of people ages 1...   NaN   NaN   NaN   NaN
# 1  Literacy rate, adult total (% of people ages 1...   NaN   NaN   NaN   NaN
#
#    1965  1966  1967  ...   2005  2006  2007  2008  2009       2010  2011  \
# 0   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN  96.822639   NaN
# 1   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN        NaN   NaN
#
#    2012  2013  2014
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
#
# [2 rows x 57 columns]

# %%
url='http://api.worldbank.org/v2/en/indicator/se.prm.enrr?downloadformat=csv'
filename='se.prm.enrr_Indicator_en_csv_v2.csv'
r = requests.get(url)
z = zipfile.ZipFile(StringIO.StringIO(r.content))
ger1=pd.read_csv(z.open(filename),skiprows=[0,1]).drop('Unnamed: 58',axis=1).drop('Indicator Code',axis=1)
ger1.head(2)
# Out:
#   Country Name Country Code                        Indicator Name  1961  1962  \
# 0        Aruba          ABW  School enrollment, primary (% gross)   NaN   NaN
# 1      Andorra          AND  School enrollment, primary (% gross)   NaN   NaN
#
#    1963  1964  1965  1966  1967  ...        2005       2006       2007  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   111.37672  114.23859  115.22441
# 1   NaN   NaN   NaN   NaN   NaN  ...         NaN        NaN        NaN
#
#         2008       2009       2010      2011       2012  2013  2014
# 0  113.07883  113.77574  113.72866  105.2194  104.06276   NaN   NaN
# 1        NaN        NaN        NaN       NaN        NaN   NaN   NaN
#
# [2 rows x 57 columns]

# %%
url='http://api.worldbank.org/v2/en/indicator/se.sec.enrr?downloadformat=csv'
filename='se.sec.enrr_Indicator_en_csv_v2.csv'
r = requests.get(url)
z = zipfile.ZipFile(StringIO.StringIO(r.content))
ger2=pd.read_csv(z.open(filename),skiprows=[0,1]).drop('Unnamed: 58',axis=1).drop('Indicator Code',axis=1)
ger2.head(2)
# Out:
#   Country Name Country Code                          Indicator Name  1961  \
# 0        Aruba          ABW  School enrollment, secondary (% gross)   NaN
# 1      Andorra          AND  School enrollment, secondary (% gross)   NaN
#
#    1962  1963  1964  1965  1966  1967  ...       2005      2006       2007  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...   95.92882  97.35637  102.54636
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN       NaN        NaN
#
#        2008      2009      2010      2011      2012  2013  2014
# 0  94.64913  96.72344  95.83605  97.01512  99.98673   NaN   NaN
# 1       NaN       NaN       NaN       NaN       NaN   NaN   NaN
#
# [2 rows x 57 columns]

# %%
url='http://api.worldbank.org/v2/en/indicator/se.ter.enrr?downloadformat=csv'
filename='se.ter.enrr_Indicator_en_csv_v2.csv'
r = requests.get(url)
z = zipfile.ZipFile(StringIO.StringIO(r.content))
ger3=pd.read_csv(z.open(filename),skiprows=[0,1]).drop('Unnamed: 58',axis=1).drop('Indicator Code',axis=1)
ger3.head(2)
# Out:
#   Country Name Country Code                         Indicator Name  1961  \
# 0        Aruba          ABW  School enrollment, tertiary (% gross)   NaN
# 1      Andorra          AND  School enrollment, tertiary (% gross)   NaN
#
#    1962  1963  1964  1965  1966  1967  ...       2005      2006      2007  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...   31.68347  30.90319  33.92613
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN       NaN       NaN
#
#        2008      2009      2010      2011      2012  2013  2014
# 0  35.24049  35.36232  37.35172  38.73762  37.76113   NaN   NaN
# 1       NaN       NaN       NaN       NaN       NaN   NaN   NaN
#
# [2 rows x 57 columns]

# %%
ids=pd.read_csv('http://bl.ocks.org/d/4090846/world-country-names.tsv',sep='\t').set_index(['name'],drop=True)
ids.head()
# Out:
#                  id
# name
# Northern Cyprus  -1
# Kosovo           -2
# Somaliland       -3
# Afghanistan       4
# Albania           8

# %%
def country_name_converter(country):
    if country=="Venezuela, Bolivarian Republic of": return "Venezuela (Bolivarian Republic of)"
    elif country=="Tanzania, United Republic of": return "Tanzania (United Republic of)"
    elif country=="Moldova, Republic of": return "Moldova (Republic of)"
    elif country=="Micronesia, Federated States of": return "Micronesia (Federated States of)"
    elif country=="Macedonia, the former Yugoslav Republic of": return "The former Yugoslav Republic of Macedonia"
    elif country=="Korea, Republic of": return "Korea (Republic of)"
    elif country=="Korea, Democratic People's Republic of": return "Korea (Democratic People's Rep. of)"
    elif country=="Côte d'Ivoire": return "C\xc3\xb4te d'Ivoire"
    elif country=="Iran, Islamic Republic of": return "Iran (Islamic Republic of)"
    elif country=="Hong Kong": return "Hong Kong, China (SAR)"
    elif country=="Palestinian Territory, Occupied": return "Palestine, State of"
    elif country=="Congo, the Democratic Republic of the": return "Congo (Democratic Republic of the)"
    elif country=="Bolivia, Plurinational State of": return "Bolivia (Plurinational State of)"
    else: return country

# %%
import re
codes={}
for i in ids.index:
    try: 
        a=[i]
        a.append(round(float(re.sub(r'[^\d.]+', '',hdi.loc[country_name_converter(i)]\
                                    [u"Human Development Index (HDI) Value, 2013"])),3))
        a.append(round((float(re.sub(r'[^\d.]+', '',hdi.loc[country_name_converter(i)]\
                                     [u"Life expectancy at birth (years), 2013"]))-20)/(85-20),3))
        a.append(round((float(re.sub(r'[^\d.]+', '',hdi.loc[country_name_converter(i)]\
                                     [u"Mean years of schooling (years), 2012 a"]))/15+\
                  float(re.sub(r'[^\d.]+', '',hdi.loc[country_name_converter(i)]\
                               [u"Expected years of schooling (years), 2012 a"]))/18)/2,3))
        a.append(round((np.log(float(re.sub(r'[^\d.]+', '',hdi.loc[country_name_converter(i)]\
                        [u"Gross national income (GNI) per capita (2011 PPP $), 2013"])))-np.log(100))\
                        /(np.log(75000)-np.log(100)),3))
        a.append(round((a[2]*a[3]*a[4])**(1.0/3.0),3))
        codes[repr(ids.loc[i][0])]=a
    except: pass

# %%
import json
file('hdi2.json','w').write(json.dumps(codes))
