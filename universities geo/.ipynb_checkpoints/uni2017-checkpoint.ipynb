# %%
import pandas as pd, numpy as np, json
data={}

# %%
for year in range(2003,2018):
    data[year]=pd.read_html('http://www.shanghairanking.com/ARWU'+repr(year)+'.html', header=0)[0].sort_index(axis=1)
    print year
# Out:
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017

# %%
#save input data for later editing
DATA={}
for year in range(2003,2018):
    DATA[year]=data[year].to_json()
file('data2017.json','w').write(json.dumps(DATA))

# %%
#load data if already saved
DATA = json.loads(open('data2017.json').read())
data={}
for year in range(2003,2018):
    data[year]=pd.read_json(DATA[repr(year)]).sort_index(axis=1)

# %%
u={}
v={}
locs=['Institution',u'Institution*']
years=[[2003,2004,2011],[2005,2006,2007,2008,2009,2010,2012,2013,2014,2015,2016,2017]]
for r in range(2):
    for year in years[r]:
        unis=[]
        for i in range(data[year]['World Rank'].count()):
            uni={}
            uni['name']=data[year].loc[i][locs[r]]
            if uni['name'] not in v:v[uni['name']]={'years':[],'ranks':[]}
            v[uni['name']]['years'].append(year)
            uni['rank']=data[year].loc[i]['World Rank']
            v[uni['name']]['ranks'].append(uni['rank'])
            unis.append(uni)
        u[year]=unis

# %%
exceptions=[]

# %%
from pygeocoder import Geocoder
apik='AIzaSyDybC2OroTE_XDJTuxjKruxFpby5VDhEGk'
counter=0
for k in v.keys():
    counter+=1
    try:
        #results = Geocoder(apik).geocode(k+' university')
        results = Geocoder(apik).geocode(k)
        v[k]["coord"]=(results[0].coordinates)
        print counter,'OK'
    except:
        print counter,'ERROR'
# Out:
# 1 OK
# 2 OK
# 3 OK
# 4 OK
# 5 OK
# 6 OK
# 7 OK
# 8 OK
# 9 OK
# 10 OK
# 11 OK
# 12 OK
# 13 OK
# 14 OK
# 15 OK
# 16 OK
# 17 OK
# 18 OK
# 19 OK
# 20 OK
# 21 OK
# 22 OK
# 23 OK
# 24 OK
# 25 OK
# 26 OK
# 27 OK
# 28 OK
# 29 OK
# 30 OK
# 31 OK
# 32 OK
# 33 OK
# 34 OK
# 35 OK
# 36 OK
# 37 OK
# 38 ERROR
# 39 OK
# 40 OK
# 41 OK
# 42 OK
# 43 OK
# 44 OK
# 45 OK
# 46 OK
# 47 OK
# 48 OK
# 49 OK
# 50 OK
# 51 OK
# 52 OK
# 53 OK
# 54 OK
# 55 OK
# 56 OK
# 57 OK
# 58 OK
# 59 OK
# 60 OK
# 61 OK
# 62 OK
# 63 OK
# 64 OK
# 65 OK
# 66 OK
# 67 OK
# 68 OK
# 69 OK
# 70 OK
# 71 OK
# 72 OK
# 73 OK
# 74 OK
# 75 OK
# 76 OK
# 77 OK
# 78 OK
# 79 OK
# 80 OK
# 81 OK
# 82 OK
# 83 ERROR
# 84 OK
# 85 OK
# 86 OK
# 87 OK
# 88 OK
# 89 OK
# 90 OK
# 91 OK
# 92 OK
# 93 OK
# 94 OK
# 95 OK
# 96 OK
# 97 OK
# 98 OK
# 99 OK
# 100 OK
# 101 OK
# 102 OK
# 103 OK
# 104 OK
# 105 OK
# 106 OK
# 107 ERROR
# 108 OK
# 109 OK
# 110 OK
# 111 OK
# 112 OK
# 113 OK
# 114 OK
# 115 OK
# 116 OK
# 117 OK
# 118 OK
# 119 OK
# 120 OK
# 121 OK
# 122 OK
# ...

# %%
for k in v.keys():
    if "coord" not in v[k]:
        print k
        if k=='Tongji University':tocode='Shanghai'
        if k=='University of Electronic Science and Technology of China':tocode='Chengdu'
        if k=='Huazhong University of Science and Technology':tocode='Wuhan'
        if k=='Hacettepe University':tocode='Ankara'
        if k=='King Abdulaziz University':tocode='Jeddah'
        results = Geocoder(apik).geocode(tocode)
        v[k]["coord"]=(results[0].coordinates)  
    elif k=='University of Cambridge':
        print k
        tocode='Cambridge, United Kingdom'
        results = Geocoder(apik).geocode(tocode)
        v[k]["coord"]=(results[0].coordinates)
# Out:
# University of Cambridge

# %%
#save results
file('u2017.json','w').write(json.dumps(u))#rankings
file('v2017.json','w').write(json.dumps(v))#universities
