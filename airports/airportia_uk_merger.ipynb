# %%
import pandas as pd, json, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pygeocoder import Geocoder
apik='AIzaSyDybC2OroTE_XDJTuxjKruxFpby5VDhEGk'

# %%
locations=json.loads(file('locations_ae.json','r').read())

# %%
mdf_dest=pd.read_json(json.loads(file('mdf_ae_dest.json','r').read()))
mdf_arrv=pd.read_json(json.loads(file('mdf_ae_arrv.json','r').read()))

# %%
citysave_dest=json.loads(file('citysave_ae_dest.json','r').read())
citysave_arrv=json.loads(file('citysave_ae_arrv.json','r').read())

# %%
mdf_dest['ID']=mdf_dest['From']
mdf_dest.head()
# Out:
#           Airline Airport       City  \
# 0      Air Arabia     DOH       Doha
# 1      Air Arabia     MCT     Muscat
# 10     Air Arabia     MCT     Muscat
# 100    Air Arabia     ISB  Islamabad
# 1000  Jet Airways     IXE  Mangalore
#
#                                                    Date From             To  \
# 0     https://www.airportia.com/united-arab-emirates...  RKT       Doha DOH
# 1     https://www.airportia.com/united-arab-emirates...  RKT     Muscat MCT
# 10    https://www.airportia.com/united-arab-emirates...  RKT     Muscat MCT
# 100   https://www.airportia.com/united-arab-emirates...  RKT  Islamabad ISB
# 1000  https://www.airportia.com/united-arab-emirates...  AUH  Mangalore IXE
#
#       index   ID
# 0         0  RKT
# 1         1  RKT
# 10        1  RKT
# 100       3  RKT
# 1000      8  AUH

# %%
mdf_arrv['ID']=mdf_arrv['To']
mdf_arrv.head()
# Out:
#              Airline Airport        City  \
# 0         Air Arabia     KTM   Kathmandu
# 1         Air Arabia     CGP  Chittagong
# 10        Air Arabia     DOH        Doha
# 100       Air Arabia     CAI       Cairo
# 1000  Etihad Airways     BLR   Bangalore
#
#                                                    Date            From   To  \
# 0     https://www.airportia.com/united-arab-emirates...   Kathmandu KTM  RKT
# 1     https://www.airportia.com/united-arab-emirates...  Chittagong CGP  RKT
# 10    https://www.airportia.com/united-arab-emirates...        Doha DOH  RKT
# 100   https://www.airportia.com/united-arab-emirates...       Cairo CAI  RKT
# 1000  https://www.airportia.com/united-arab-emirates...   Bangalore BLR  AUH
#
#       index   ID
# 0         0  RKT
# 1         1  RKT
# 10        2  RKT
# 100       2  RKT
# 1000      9  AUH

# %%
mdf=pd.concat([mdf_dest,mdf_arrv])

# %%
len(mdf_dest)
# Out:
# 13003

# %%
len(mdf_arrv)
# Out:
# 12955

# %%
mdf
# Out:
#                                Airline Airport                City  \
# 0                           Air Arabia     DOH                Doha
# 1                           Air Arabia     MCT              Muscat
# 10                          Air Arabia     MCT              Muscat
# 100                         Air Arabia     ISB           Islamabad
# 1000                       Jet Airways     IXE           Mangalore
# 10000                         Emirates     BCN           Barcelona
# 10001                         FlyDubai     MLE                Male
# 10002                         Emirates     ZRH              Zurich
# 10003                         FlyDubai     KTM           Kathmandu
# 10004                Cameroon Airlines     JED              Jeddah
# 10005           Saudi Arabian Airlines     RUH              Riyadh
# 10006                         Emirates     BOM              Mumbai
# 10007                         Emirates     MUC              Munich
# 10008                         Emirates     DMM              Dammam
# 10009                         Emirates     LHR              London
# 1001                  Turkish Airlines     IST            Istanbul
# 10010                      Jet Airways     BOM              Mumbai
# 10018                     DXB    Bahrain BAH    401  DXB
# 10019                     DXB       Doha DOH    402  DXB
# 1002                      AUH     Medina MED     10  AUH
# 10020                     DXB     Muscat MCT    403  DXB
# 10021                     DXB     Moscow SVO    404  DXB
# 10022                     DXB      Dhaka DAC    405  DXB
# ...                       ...            ...    ...  ...
# 9972              Yerevan EVN            DXB    430  DXB
# 9973          Los Angeles LAX            DXB    431  DXB
# 9974               Boston BOS            DXB    432  DXB
# 9975               Jeddah JED            DXB    433  DXB
# 9976                Paris CDG            DXB    434  DXB
# 9977             Ashgabat ASB            DXB    435  DXB
# 9978                Ha'il HAS            DXB    436  DXB
# 9979      Fort Lauderdale FLL            DXB    437  DXB
# 998                 Perth PER            AUH      7  AUH
# 9980           Manchester MAN            DXB    438  DXB
# 9981              Seattle SEA            DXB    439  DXB
# 9982              Bahrain BAH            DXB    440  DXB
# 9983                Delhi DEL            DXB    441  DXB
# 9984          Kuwait City KWI            DXB    442  DXB
# 9985               Muscat MCT            DXB    443  DXB
# 9986               Samara KUF            DXB    444  DXB
# 9987              Bangkok BKK            DXB    445  DXB
# 9988              Bahrain BAH            DXB    446  DXB
# 9989              Tbilisi TBS            DXB    447  DXB
# 999             Kathmandu KTM            AUH      8  AUH
# 9990               London LHR            DXB    448  DXB
# 9991   Thiruvananthapuram TRV            DXB    449  DXB
# 9992                 Doha DOH            DXB    450  DXB
# 9993               Shiraz SYZ            DXB    451  DXB
# 9994             New York JFK            DXB    452  DXB
# 9995            Bucharest OTP            DXB    453  DXB
# 9996          Kuwait City KWI            DXB    454  DXB
# 9997               Muscat MCT            DXB    455  DXB
# 9998               Almaty ALA            DXB    456  DXB
# 9999                 Doha DOH            DXB    457  DXB
#
# [25958 rows x 8 columns]

# %%
mdg=mdf.set_index(['ID','City','Airport','Airline'])

# %%
flights={}
minn=1.0 #want to see minimum 1 flight in the past 2 weeks
for i in mdg.index.get_level_values(0).unique():
    #2 weeks downloaded. want to get weekly freq. but multi by 2 dept+arrv
    d=4.0
    if i not in flights:flights[i]={}
    for j in mdg.loc[i].index.get_level_values(0).unique():
        if len(mdg.loc[i].loc[j])>minn: #minimum 1 flights required in this period at least once every 2 weeks
            if j not in flights[i]:flights[i][j]={'airports':{},'7freq':0}
            flights[i][j]['7freq']=len(mdg.loc[i].loc[j])/d 
            for k in mdg.loc[i].loc[j].index.get_level_values(0).unique():
                if len(mdg.loc[i].loc[j].loc[k])>minn:
                    if k not in flights[i][j]['airports']:flights[i][j]['airports'][k]={'airlines':{},'7freq':0}
                    flights[i][j]['airports'][k]['7freq']=len(mdg.loc[i].loc[j].loc[k])/d
                    for l in mdg.loc[i].loc[j].loc[k].index.get_level_values(0).unique():
                        try:
                            if len(mdg.loc[i].loc[j].loc[k].loc[l])>minn: 
                                if l not in flights[i][j]['airports'][k]['airlines']:flights[i][j]['airports'][k]['airlines'][l]={'7freq':0}
                                flights[i][j]['airports'][k]['airlines'][l]['7freq']=len(mdg.loc[i].loc[j].loc[k].loc[l])/d
                        except:pass

# %%
file("flights_ae.json",'w').write(json.dumps(flights))
