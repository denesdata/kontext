# %%
import pandas as pd, json, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pygeocoder import Geocoder
apik='AIzaSyDybC2OroTE_XDJTuxjKruxFpby5VDhEGk'

# %%
locations=json.loads(file('locations_jo.json','r').read())

# %%
mdf_dest=pd.read_json(json.loads(file('mdf_jo_dest.json','r').read()))
mdf_arrv=pd.read_json(json.loads(file('mdf_jo_arrv.json','r').read()))

# %%
citysave_dest=json.loads(file('citysave_jo_dest.json','r').read())
citysave_arrv=json.loads(file('citysave_jo_arrv.json','r').read())

# %%
mdf_dest['ID']=mdf_dest['From']
mdf_dest.head()
# Out:
#               Airline Airport      City  \
# 0     Royal Jordanian     KRT  Khartoum
# 1      Tarco Airlines     KRT  Khartoum
# 10    Royal Jordanian     JED    Jeddah
# 100          Oman Air     MCT    Muscat
# 1000              MEA     BEY    Beirut
#
#                                                    Date From            To  \
# 0     https://www.airportia.com/jordan/queen-alia-in...  AMM  Khartoum KRT
# 1     https://www.airportia.com/jordan/queen-alia-in...  AMM  Khartoum KRT
# 10    https://www.airportia.com/jordan/queen-alia-in...  AMM    Jeddah JED
# 100   https://www.airportia.com/jordan/queen-alia-in...  AMM    Muscat MCT
# 1000  https://www.airportia.com/jordan/queen-alia-in...  AMM    Beirut BEY
#
#       index   ID
# 0         0  AMM
# 1         1  AMM
# 10       10  AMM
# 100       3  AMM
# 1000     73  AMM

# %%
mdf_arrv['ID']=mdf_arrv['To']
mdf_arrv.head()
# Out:
#                      Airline Airport         City  \
# 0                   EgyptAir     CAI        Cairo
# 1            Royal Jordanian     BEY       Beirut
# 10           Royal Jordanian     KWI  Kuwait City
# 100          Royal Jordanian     KWI  Kuwait City
# 1000  Saudi Arabian Airlines     JED       Jeddah
#
#                                                    Date             From   To  \
# 0     https://www.airportia.com/jordan/queen-alia-in...        Cairo CAI  AMM
# 1     https://www.airportia.com/jordan/queen-alia-in...       Beirut BEY  AMM
# 10    https://www.airportia.com/jordan/queen-alia-in...  Kuwait City KWI  AMM
# 100   https://www.airportia.com/jordan/queen-alia-in...  Kuwait City KWI  AMM
# 1000  https://www.airportia.com/jordan/queen-alia-in...       Jeddah JED  AMM
#
#       index   ID
# 0         0  AMM
# 1         1  AMM
# 10       10  AMM
# 100       9  AMM
# 1000     80  AMM

# %%
mdf=pd.concat([mdf_dest,mdf_arrv])

# %%
len(mdf_dest)
# Out:
# 1341

# %%
len(mdf_arrv)
# Out:
# 1336

# %%
mdf
# Out:
#                      Airline Airport         City  \
# 0            Royal Jordanian     KRT     Khartoum
# 1             Tarco Airlines     KRT     Khartoum
# 10           Royal Jordanian     JED       Jeddah
# 100                 Oman Air     MCT       Muscat
# 1000                     MEA     BEY       Beirut
# 1001                EgyptAir     CAI        Cairo
# 1002         Royal Jordanian     JED       Jeddah
# 1003         Jazeera Airways     KWI  Kuwait City
# 1004           Qatar Airways     DOH         Doha
# 1005  Saudi Arabian Airlines     RUH       Riyadh
# 1006         Royal Jordanian     EBL        Arbil
# 1007         Royal Jordanian     AUH    Abu Dhabi
# 1008                FlyEgypt     HBE   Alexandria
# 1009                Gulf Air     BAH      Bahrain
# 101                 Emirates     DXB        Dubai
# 1010              Air Arabia     SHJ      Sharjah
# 1011         Royal Jordanian     BEY       Beirut
# 1012         Royal Jordanian     TLV     Tel Aviv
# 1013         Royal Jordanian     DXB        Dubai
# 985   https://www.airportia.com/jordan/queen-alia-in...         Rome FCO
# 986   https://www.airportia.com/jordan/queen-alia-in...    Frankfurt FRA
# 987   https://www.airportia.com/jordan/queen-alia-in...  Kuwait City KWI
# 988   https://www.airportia.com/jordan/queen-alia-in...       Riyadh RUH
# 989   https://www.airportia.com/jordan/queen-alia-in...    Frankfurt FRA
# 99    https://www.airportia.com/jordan/queen-alia-in...       Jeddah JED
# 990   https://www.airportia.com/jordan/queen-alia-in...  Kuwait City KWI
# 991   https://www.airportia.com/jordan/queen-alia-in...        Tunis TUN
# 992   https://www.airportia.com/jordan/queen-alia-in...      Bahrain BAH
# 993   https://www.airportia.com/jordan/queen-alia-in...      Larnaca LCA
# 994   https://www.airportia.com/jordan/queen-alia-in...        Paris CDG
# 995   https://www.airportia.com/jordan/queen-alia-in...      Sharjah SHJ
# 996   https://www.airportia.com/jordan/queen-alia-in...       Moscow DME
# 997   https://www.airportia.com/jordan/queen-alia-in...       Riyadh RUH
# 998   https://www.airportia.com/jordan/queen-alia-in...       Riyadh RUH
# 999   https://www.airportia.com/jordan/queen-alia-in...        Dubai DXB
#
#                    To  index   ID
# 0        Khartoum KRT      0  AMM
# 1        Khartoum KRT      1  AMM
# 10         Jeddah JED     10  AMM
# 100        Muscat MCT      3  AMM
# 1000       Beirut BEY     73  AMM
# 1001        Cairo CAI     74  AMM
# 1002       Jeddah JED     75  AMM
# 1003  Kuwait City KWI     76  AMM
# 1004         Doha DOH     77  AMM
# 1005       Riyadh RUH     78  AMM
# 1006        Arbil EBL     79  AMM
# 1007    Abu Dhabi AUH     80  AMM
# 1008   Alexandria HBE     81  AMM
# 1009      Bahrain BAH     82  AMM
# 101         Dubai DXB      4  AMM
# 1010      Sharjah SHJ     83  AMM
# 1011       Beirut BEY     84  AMM
# 1012     Tel Aviv TLV     85  AMM
# 1013        Dubai DXB     86  AMM
# 1014       Jeddah JED     87  AMM
# 1015       Medina MED     88  AMM
# 1016       Riyadh RUH     89  AMM
# 1017  Kuwait City KWI     90  AMM
# 1018        Cairo CAI     91  AMM
# 1019        Dubai DXB     92  AMM
# 102     Frankfurt FRA      5  AMM
# 1020       Jeddah JED     93  AMM
# 1021     Khartoum KRT      0  AMM
# 1022        Paris CDG      1  AMM
# 1023        Arbil EBL      2  AMM
# ...               ...    ...  ...
# 972               AMM     52  AMM
# 973               AMM     53  AMM
# 974               AMM     54  AMM
# 975               AMM     55  AMM
# 976               AMM     56  AMM
# 977               AMM     57  AMM
# 978               AMM     58  AMM
# 979               AMM     59  AMM
# 98                AMM      7  AMM
# 980               AMM     60  AMM
# 981               AMM     61  AMM
# 982               AMM     62  AMM
# 983               AMM     63  AMM
# 984               AMM     64  AMM
# 985               AMM     65  AMM
# 986               AMM     66  AMM
# 987               AMM     67  AMM
# 988               AMM     68  AMM
# 989               AMM     69  AMM
# 99                AMM      8  AMM
# 990               AMM     70  AMM
# 991               AMM     71  AMM
# 992               AMM     72  AMM
# 993               AMM     73  AMM
# 994               AMM     74  AMM
# 995               AMM     75  AMM
# 996               AMM     76  AMM
# 997               AMM     77  AMM
# 998               AMM     78  AMM
# 999               AMM     79  AMM
#
# [2677 rows x 8 columns]

# %%
mdg=mdf.set_index(['ID','City','Airport','Airline'])

# %%
k=mdg.loc['AMM'].loc['Frankfurt'].loc['FRA']
testurl=u'https://www.airportia.com/jordan/queen-alia-international-airport/departures/20170318'
k[k['Date']==testurl]
# Out:
#                                                               Date From  \
# Airline
# Lufthansa        https://www.airportia.com/jordan/queen-alia-in...  AMM
# Royal Jordanian  https://www.airportia.com/jordan/queen-alia-in...  AMM
#
#                             To  index
# Airline
# Lufthansa        Frankfurt FRA      7
# Royal Jordanian  Frankfurt FRA     43

# %%
k=mdg.loc['AMM'].loc['Frankfurt'].loc['FRA']
testurl=u'https://www.airportia.com/jordan/queen-alia-international-airport/arrivals/20170318'
k[k['Date']==testurl]
# Out:
#                                                               Date  \
# Airline
# Lufthansa        https://www.airportia.com/jordan/queen-alia-in...
# Royal Jordanian  https://www.airportia.com/jordan/queen-alia-in...
#
#                           From   To  index
# Airline
# Lufthansa        Frankfurt FRA  AMM     63
# Royal Jordanian  Frankfurt FRA  AMM     79

# %%
k=mdg.loc['AMM'].loc['Frankfurt'].loc['FRA']
for i in range(11,25):
    testurl=u'https://www.airportia.com/jordan/queen-alia-international-airport/departures/201703'+str(i)
    print 'AMM-FRA March',i, 'departures',len(k[k['Date']==testurl]),
    testurl=u'https://www.airportia.com/jordan/queen-alia-international-airport/arrivals/201703'+str(i)
    print 'arrivals', len(k[k['Date']==testurl])
# Out:
# AMM-FRA March 11 departures 2 arrivals 2
# AMM-FRA March 12 departures 2 arrivals 2
# AMM-FRA March 13 departures 2 arrivals 2
# AMM-FRA March 14 departures 1 arrivals 1
# AMM-FRA March 15 departures 2 arrivals 1
# AMM-FRA March 16 departures 2 arrivals 2
# AMM-FRA March 17 departures 2 arrivals 2
# AMM-FRA March 18 departures 2 arrivals 2
# AMM-FRA March 19 departures 2 arrivals 2
# AMM-FRA March 20 departures 2 arrivals 2
# AMM-FRA March 21 departures 1 arrivals 1
# AMM-FRA March 22 departures 2 arrivals 1
# AMM-FRA March 23 departures 2 arrivals 2
# AMM-FRA March 24 departures 2 arrivals 2

# %%
len(k)/14
# Out:
# 3

# %% [markdown]
# `mdg` checks out with source

# %%
flights={}
minn=1.0 #want to see minimum 1 flight in the past 2 weeks
for i in mdg.index.get_level_values(0).unique():
    #2 weeks downloaded. want to get weekly freq. but multi by 2 dept+arrv
    d=4.0
    if i not in flights:flights[i]={}
    for j in mdg.loc[i].index.get_level_values(0).unique():
        if len(mdg.loc[i].loc[j])>minn: #minimum 1 flights required in this period at least once every 2 weeks
            if j not in flights[i]:flights[i][j]={'airports':{},'7freq':0}
            flights[i][j]['7freq']=len(mdg.loc[i].loc[j])/d 
            for k in mdg.loc[i].loc[j].index.get_level_values(0).unique():
                if len(mdg.loc[i].loc[j].loc[k])>minn:
                    if k not in flights[i][j]['airports']:flights[i][j]['airports'][k]={'airlines':{},'7freq':0}
                    flights[i][j]['airports'][k]['7freq']=len(mdg.loc[i].loc[j].loc[k])/d
                    for l in mdg.loc[i].loc[j].loc[k].index.get_level_values(0).unique():
                        try:
                            if len(mdg.loc[i].loc[j].loc[k].loc[l])>minn: 
                                if l not in flights[i][j]['airports'][k]['airlines']:flights[i][j]['airports'][k]['airlines'][l]={'7freq':0}
                                flights[i][j]['airports'][k]['airlines'][l]['7freq']=len(mdg.loc[i].loc[j].loc[k].loc[l])/d
                        except:pass

# %%
file("flights_jo.json",'w').write(json.dumps(flights))
